# %% [markdown]
# <a href="https://colab.research.google.com/github/rajkonkret/analiza_danych_9_09_2026/blob/main/analiza_danych_9_09_2026_zad2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# /content/AAPL_stock_price_example.csv
#
# plik csv - dane oddzielone znakiem podziału -> ;,tab, space, |

# %%
import numpy as np

# %%
input_stock_price_array = np.genfromtxt(
    'AAPL_stock_price_example.csv',
    delimiter=",",
    names=True, # pierwszy wiersz traktuja jako nazwy kolumn
    usecols=(1,) # wczytaj kolumne index 1
)

# %%
print(input_stock_price_array)
# Out:
# [(157.919998,) (142.190002,) (148.259995,) (147.929993,) (150.75    ,)
#  (153.309998,) (153.800003,) (152.289993,) (150.      ,) (153.070007,)
#  (154.940002,) (155.860001,) (156.820007,) (153.300003,) (153.919998,)
#  (152.699997,) (157.759995,) (156.300003,) (154.679993,) (165.25    ,)
#  (166.440002,) (166.520004,) (171.25    ,) (174.179993,) (174.240005,)
#  (170.940002,) (170.410004,) (169.429993,) (170.889999,) (170.179993,)
#  (170.800003,) (170.419998,) (170.929993,) (172.029999,) (171.059998,)
#  (172.970001,) (174.229996,) (174.330002,) (174.869995,) (173.149994,)
#  (174.970001,) (175.850006,) (175.529999,) (174.520004,) (172.5     ,)
#  (172.910004,) (178.899994,) (180.910004,) (181.710007,) (183.729996,)
#  (186.119995,) (188.020004,) (186.529999,) (188.160004,) (195.089996,)
#  (191.050003,) (188.740005,) (186.789993,) (188.470001,) (188.720001,)
#  (189.949997,) (191.240005,) (194.020004,) (195.350006,) (195.690002,)
# ...

# %%
print(input_stock_price_array.size)
# Out:
# 229

# %%
# pięc pierwszych
print(input_stock_price_array[:5])
# Out:
# [(157.919998,) (142.190002,) (148.259995,) (147.929993,) (150.75    ,)]

# %%
# '<f8' eloat 8 bajtowy -> 64
input_stock_price_array.dtype
# Out:
# dtype([('Close', '<f8')])

# %%
# [::-1] - odwróćenie kolekcji
sorted_stock_price = np.sort(input_stock_price_array)[::-1]
print(sorted_stock_price)
# Out:
# [(267.100006,) (266.369995,) (266.290009,) (265.76001 ,) (264.470001,)
#  (264.290009,) (263.190002,) (262.640015,) (262.200012,) (262.01001 ,)
#  (261.959991,) (261.779999,) (260.140015,) (259.429993,) (257.5     ,)
#  (257.23999 ,) (257.130005,) (255.820007,) (249.050003,) (248.759995,)
#  (246.580002,) (243.580002,) (243.289993,) (243.259995,) (243.179993,)
#  (240.509995,) (239.960007,) (236.410004,) (236.210007,) (235.869995,)
#  (235.320007,) (235.279999,) (234.369995,) (230.089996,) (227.059998,)
#  (227.029999,) (227.009995,) (224.589996,) (224.399994,) (223.970001,)
#  (223.589996,) (223.089996,) (222.770004,) (221.029999,) (220.960007,)
#  (220.820007,) (220.699997,) (219.899994,) (219.889999,) (218.960007,)
#  (218.820007,) (218.75    ,) (218.720001,) (217.729996,) (217.679993,)
#  (216.699997,) (214.169998,) (213.279999,) (213.259995,) (213.039993,)
#  (212.639999,) (212.460007,) (211.75    ,) (210.520004,) (210.360001,)
# ...

# %%
print(sorted_stock_price[0])
# Out:
# (267.100006,)

# %% [markdown]
# # Pandas
# Najpopularniejsza biblioteka do przetwarzania danych\
# DataFrame, Series

# %%
import pandas as pd
# !pip install pandas

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
miasta = ["Kielce", "Poznań", 'Warszawa', 'Kraków']

# %%
product_data = {
    "product a" : [13, 20, 0, 10],
    "product b": [10, 30, 17, 10],
    "product c" : [6, 9, 10, 0]
}

# %%
# tworzymy DataFrame(tabela)
data = pd.DataFrame(product_data, index=miasta)

# %%
print(data)
# Out:
#           product a  product b  product c
# Kielce           13         10          6
# Poznań           20         30          9
# Warszawa          0         17         10
# Kraków           10         10          0

# %%
data
# Out:
#           product a  product b  product c
# Kielce           13         10          6
# Poznań           20         30          9
# Warszawa          0         17         10
# Kraków           10         10          0

# %%
product_sales_sum = data.sum()
display(product_sales_sum)
# Out:
# product a    43
# product b    67
# product c    25
# dtype: int64

# %% [markdown]
# wykres

# %%
from matplotlib import pyplot as plt

# %%
data['product b'].plot(kind='hist', bins=30, title="product b")
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data
# Out:
#           product a  product b  product c
# Kielce           13         10          6
# Poznań           20         30          9
# Warszawa          0         17         10
# Kraków           10         10          0

# %%
data.loc["Warszawa"]
# Out:
# product a     0
# product b    17
# product c    10
# Name: Warszawa, dtype: int64

# %%
data.loc["Warszawa"] > 10
# Out:
# product a    False
# product b     True
# product c    False
# Name: Warszawa, dtype: bool

# %%
# Kielce
data.loc["Kielce"] > 6
# Out:
# product a     True
# product b     True
# product c    False
# Name: Kielce, dtype: bool

# %% [markdown]
# ---

# %%
df = pd.read_csv('AAPL_stock_price_example.csv')
df
# Out:
#            Date       Close
# 0    2019-01-02  157.919998
# 1    2019-01-03  142.190002
# 2    2019-01-04  148.259995
# 3    2019-01-07  147.929993
# 4    2019-01-08  150.750000
# ..          ...         ...
# 224  2019-11-20  263.190002
# 225  2019-11-21  262.010010
# 226  2019-11-22  261.779999
# 227  2019-11-25  266.369995
# 228  2019-11-26  264.290009
#
# [229 rows x 2 columns]

# %%
print(df)
# Out:
#            Date       Close
# 0    2019-01-02  157.919998
# 1    2019-01-03  142.190002
# 2    2019-01-04  148.259995
# 3    2019-01-07  147.929993
# 4    2019-01-08  150.750000
# ..          ...         ...
# 224  2019-11-20  263.190002
# 225  2019-11-21  262.010010
# 226  2019-11-22  261.779999
# 227  2019-11-25  266.369995
# 228  2019-11-26  264.290009
#
# [229 rows x 2 columns]

# %%
df.describe()
# Out:
#             Close
# count  229.000000
# mean   201.477598
# std     28.246961
# min    142.190002
# 25%    182.539993
# 50%    200.720001
# 75%    213.279999
# max    267.100006

# %%
# openpyxl
# !pip install openpyxl
df.to_excel('dane_akcje_apple.xlsx')

# %%
df.to_excel('dane_akcje_apple_no_index.xlsx', index=False)

# %% [markdown]
# ---

# %%
df = pd.read_csv('evolution_of_data_analysis.csv')
df
# Out:
#    Year|Decade|Milestone Title|Milestone Event|Why Important|Reference|People Process or Technology Tag
# 0   1945|1940s|ENIAC|First electronic general-purp...
# 1   1945|1940s|John von Neumann / array|"John von ...
# 2   1956|1950s|First Hard Disk|The first computer ...
# 3   1958|1950s|Modem|The modem invented|"Communica...
# 4   1961|1960s|John Tukey / data analysis|Statisti...
# 5   1970|1970s|Dr. EF Codd / normalized data|"Dr. ...
# 6   1972|1970s|FORTRAN supports CSV Files|FORTRAN ...
# 7   1982|1980s|Mike Bloomberg / Terminal|Bloomberg...
# 8   1983|1980s|Edward Tufty / Data Viz concepts|"E...
# 9   1986|1980s|SQL Standardized|SQL Language Stand...
# 10  1987|1980s|MS Excel|Microsoft Excel|Mainstream...
# 11  1989|1980s|BI (Business Intelligence)|The term...
# 12  1990|1990s|OLAP|On-Line Analytical Processing ...
# 13  1990|1990s|Guido van Rossum / Python |Guido va...
# 14  1991|1990s|Linus Torvalds / Linux OS|Finnish e...
# ...

# %%
df = pd.read_csv('evolution_of_data_analysis.csv', delimiter="|")
df
# Out:
#     Year Decade                      Milestone Title  \
# 0   1945  1940s                                ENIAC
# 1   1945  1940s             John von Neumann / array
# 2   1956  1950s                      First Hard Disk
# 3   1958  1950s                                Modem
# 4   1961  1960s           John Tukey / data analysis
# 5   1970  1970s        Dr. EF Codd / normalized data
# 6   1972  1970s           FORTRAN supports CSV Files
# 7   1982  1980s            Mike Bloomberg / Terminal
# 8   1983  1980s     Edward Tufty / Data Viz concepts
# 9   1986  1980s                     SQL Standardized
# 10  1987  1980s                             MS Excel
# 11  1989  1980s           BI (Business Intelligence)
# 12  1990  1990s                                 OLAP
# 13  1990  1990s           Guido van Rossum / Python
# 14  1991  1990s            Linus Torvalds / Linux OS
# 15  1993  1990s          Bill Inmon / Data Warehouse
# 16  1993  1990s                             QlikView
# ...

# %%
# wykrycie delimitera
import csv

# context manager
with open('/content/evolution_of_data_analysis.csv') as csv_f:
    dialect = csv.Sniffer().sniff(csv_f.read(1024))
    print(dialect.delimiter)
    print(dialect.quotechar)

    delimiter = dialect.delimiter

    csv_f.seek(0) # powrót na początek pliku
# Out:
# |
# "

# %%
df = pd.read_csv('evolution_of_data_analysis.csv', delimiter=delimiter)
df
# Out:
#     Year Decade                      Milestone Title  \
# 0   1945  1940s                                ENIAC
# 1   1945  1940s             John von Neumann / array
# 2   1956  1950s                      First Hard Disk
# 3   1958  1950s                                Modem
# 4   1961  1960s           John Tukey / data analysis
# 5   1970  1970s        Dr. EF Codd / normalized data
# 6   1972  1970s           FORTRAN supports CSV Files
# 7   1982  1980s            Mike Bloomberg / Terminal
# 8   1983  1980s     Edward Tufty / Data Viz concepts
# 9   1986  1980s                     SQL Standardized
# 10  1987  1980s                             MS Excel
# 11  1989  1980s           BI (Business Intelligence)
# 12  1990  1990s                                 OLAP
# 13  1990  1990s           Guido van Rossum / Python
# 14  1991  1990s            Linus Torvalds / Linux OS
# 15  1993  1990s          Bill Inmon / Data Warehouse
# 16  1993  1990s                             QlikView
# ...

# %%
df.describe()
# Out:
#               Year
# count    42.000000
# mean   1993.833333
# std      18.876901
# min    1945.000000
# 25%    1987.500000
# 50%    1999.000000
# 75%    2006.750000
# max    2018.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Year                              42 non-null     int64
#  1   Decade                            42 non-null     object
#  2   Milestone Title                   42 non-null     object
#  3   Milestone Event                   42 non-null     object
#  4   Why Important                     42 non-null     object
#  5   Reference                         39 non-null     object
#  6   People Process or Technology Tag  42 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.4+ KB

# %%
df.head() # 5 pierwszych wierszy
# Out:
#    Year Decade             Milestone Title  \
# 0  1945  1940s                       ENIAC
# 1  1945  1940s    John von Neumann / array
# 2  1956  1950s             First Hard Disk
# 3  1958  1950s                       Modem
# 4  1961  1960s  John Tukey / data analysis
#
#                                      Milestone Event  \
# 0  First electronic general-purpose computer = ENIAC
# 1  John von Neumann creates a merge sort algorith...
# 2                  The first computer hard disk used
# 3                                 The modem invented
# 4      Statistician John Tukey defined data analysis
#
#                                        Why Important  \
# 0   Faster decisions using a computer and mathmatics
# 1  Arrays allow mathmatics| grouping and sorting ...
# 2  Storing data for reuse = reduces time to recre...
# 3  Communication between computers| foundation of...
# 4  Defined the process and procedures of collecti...
#
# ...

# %%
df.tail()  # pięc ostatnich
# Out:
#     Year Decade            Milestone Title  \
# 37  2012  2010s               Raspberry PI
# 38  2012  2010s             Alberto Cairo
# 39  2015  2010s           Jupyter Notebook
# 40  2015  2010s                      Alexa
# 41  2018  2010s  The Data Literacy Project
#
#                                       Milestone Event  \
# 37                       Creation of the Raspberry PI
# 38  Alberto Cairo publishes the "The Functional Ar...
# 39                                    Project Jupyter
# 40                             Amazon Alexa Ecosystem
# 41                 The Data Literacy Project launches
#
#                                         Why Important  \
# 37  Making the IOT (Internet of Things) mass scale...
# 38  Charts become an artform and careers like data...
# 39  Open Source code and libraries becomes an all ...
# 40  Making voice to data mainstream and allowing A...
# 41  Building a data driven culture where anyone ca...
#
# ...

# %%
df.shape
# Out:
# (42, 7)

# %% [markdown]
# ------

# %%
movies_df = pd.read_csv("/content/IMDB-Movie-Data-with-duplicates-and-nulls.csv")
movies_df
# Out:
#       Rank                    Title                     Genre  \
# 0        1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1        2               Prometheus  Adventure,Mystery,Sci-Fi
# 2        3                    Split           Horror,Thriller
# 3        4                     Sing   Animation,Comedy,Family
# 4        5            Suicide Squad  Action,Adventure,Fantasy
# ...    ...                      ...                       ...
# 1000     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1001     2               Prometheus  Adventure,Mystery,Sci-Fi
# 1002     3                    Split           Horror,Thriller
# 1003     4                     Sing   Animation,Comedy,Family
# 1004     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# 0     A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movies_df = pd.read_csv("/content/IMDB-Movie-Data-with-duplicates-and-nulls.csv", index_col="Title")
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1005 entries, Guardians of the Galaxy to Suicide Squad
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1005 non-null   int64
#  1   Genre               1004 non-null   object
#  2   Description         1005 non-null   object
#  3   Director            1004 non-null   object
#  4   Actors              1005 non-null   object
#  5   Year                1004 non-null   float64
#  6   Runtime (Minutes)   1004 non-null   float64
#  7   Rating              1004 non-null   float64
#  8   Votes               1004 non-null   float64
#  9   Revenue (Millions)  876 non-null    float64
#  10  Metascore           940 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 126.5+ KB

# %%
# movies_df[movies_df.index.duplicated(keep=False)] wymuszenie unikalności indeksu

# %%
movies_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1005.000000  1004.000000        1004.000000  1004.000000  1.004000e+03
# mean    498.024876  2012.789841         113.205179     6.725697  1.708593e+05
# std     290.220129     3.203104          18.780724     0.944965  1.897133e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     247.000000  2010.000000         100.000000     6.200000  3.631950e+04
# 50%     498.000000  2014.000000         111.000000     6.800000  1.111915e+05
# 75%     749.000000  2016.000000         123.000000     7.400000  2.414465e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          876.000000  940.000000
# mean            83.862888   58.993617
# std            103.902363   17.179624
# min              0.000000   11.000000
# 25%             13.375000   47.000000
# ...

# %%
movies_df.duplicated().any()  # czy są duplikaty
# Out:
# np.True_

# %%
movies_df.duplicated().sum() # suma dupliaktów
# Out:
# np.int64(5)

# %%
movies_df['Rank'].duplicated().sum()
# Out:
# np.int64(5)

# %%
movies_df.duplicated()
# Out:
# Title
# Guardians of the Galaxy    False
# Prometheus                 False
# Split                      False
# Sing                       False
# Suicide Squad              False
#                            ...
# Guardians of the Galaxy     True
# Prometheus                  True
# Split                       True
# Sing                        True
# Suicide Squad               True
# Length: 1005, dtype: bool

# %%
# movies_df.duplicated('Title') # na początku

# %%
movies_df[movies_df.duplicated() == True]  # wyświetlienie duplikatów
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df[movies_df.duplicated(keep=False)]
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
movies_df_not_dupl = movies_df.drop_duplicates() # usunięcie duplikatów
movies_df_not_dupl.head(2)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              Director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                            Year  Runtime (Minutes)  Rating     Votes  \
# Title
# Guardians of the Galaxy  2014.0              121.0     8.1  757074.0
# ...

# %%
movies_df_not_dupl.duplicated().any()
# Out:
# np.False_

# %%
movies_df.rename(columns={"Runtime (Minutes)": "Runtime"})
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.head(1)
# Out:
#                          Rank                    Genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
#
#                            Director  \
# Title
# Guardians of the Galaxy  James Gunn
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
#
#                            Year  Runtime (Minutes)  Rating     Votes  \
# Title
# Guardians of the Galaxy  2014.0              121.0     8.1  757074.0
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0

# %%
movies_df.rename(columns={"Runtime (Minutes)": "Runtime"}, inplace=True) # zmien oryginał

# %%
movies_df.head(2)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              Director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                            Year  Runtime  Rating     Votes  \
# Title
# Guardians of the Galaxy  2014.0    121.0     8.1  757074.0
# ...

# %%
# zamian nazw kolumn na małe litery
movies_df.columns = [col.lower() for col in movies_df]
movies_df.head(2)
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                            year  runtime  rating     votes  \
# Title
# Guardians of the Galaxy  2014.0    121.0     8.1  757074.0
# ...

# %%
movies_df.sample()
# Out:
#         rank                   genre  \
# Title
# Morgan   194  Horror,Sci-Fi,Thriller
#
#                                               description    director  \
# Title
# Morgan  A corporate risk-management consultant must de...  Luke Scott
#
#                                                    actors    year  runtime  \
# Title
# Morgan  Kate Mara, Anya Taylor-Joy, Rose Leslie, Micha...  2016.0     92.0
#
#         rating    votes  revenue (millions)  metascore
# Title
# Morgan     5.8  22107.0                3.91       48.0

# %%
movies_df.isnull().sum().to_json("dane.json") # liczy ile elementów jest null

# %%
# usunięcie elemntów null
movies_df.dropna()
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.isnull().sum().to_json("dane2345.json") # liczy ile elementów jest null

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1005 entries, Guardians of the Galaxy to Suicide Squad
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   rank                1005 non-null   int64
#  1   genre               1004 non-null   object
#  2   description         1005 non-null   object
#  3   director            1004 non-null   object
#  4   actors              1005 non-null   object
#  5   year                1004 non-null   float64
#  6   runtime             1004 non-null   float64
#  7   rating              1004 non-null   float64
#  8   votes               1004 non-null   float64
#  9   revenue (millions)  876 non-null    float64
#  10  metascore           940 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 126.5+ KB

# %%
# wczytanie kolumny
rev = movies_df['revenue (millions)']
rev.head()
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
# Name: revenue (millions), dtype: float64

# %%
rev.mean()
# Out:
# np.float64(83.86288812785388)

# %%
rev.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1005 entries, Guardians of the Galaxy to Suicide Squad
# Series name: revenue (millions)
# Non-Null Count  Dtype
# --------------  -----
# 876 non-null    float64
# dtypes: float64(1)
# memory usage: 48.0+ KB

# %%
rev.isnull()
# Out:
# Title
# Guardians of the Galaxy    False
# Prometheus                 False
# Split                      False
# Sing                       False
# Suicide Squad              False
#                            ...
# Guardians of the Galaxy    False
# Prometheus                 False
# Split                      False
# Sing                       False
# Suicide Squad              False
# Name: revenue (millions), Length: 1005, dtype: bool

# %%
rev.isnull().sum()
# Out:
# np.int64(129)

# %%
rev.isna()
# Out:
# Title
# Guardians of the Galaxy    False
# Prometheus                 False
# Split                      False
# Sing                       False
# Suicide Squad              False
#                            ...
# Guardians of the Galaxy    False
# Prometheus                 False
# Split                      False
# Sing                       False
# Suicide Squad              False
# Name: revenue (millions), Length: 1005, dtype: bool

# %%
rev.notna() # tu gdzie nie ma null
# Out:
# Title
# Guardians of the Galaxy    True
# Prometheus                 True
# Split                      True
# Sing                       True
# Suicide Squad              True
#                            ...
# Guardians of the Galaxy    True
# Prometheus                 True
# Split                      True
# Sing                       True
# Suicide Squad              True
# Name: revenue (millions), Length: 1005, dtype: bool

# %%
rev = rev.fillna(rev.mean()) # wypęłnienie wartościa

# %%
rev
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
# Name: revenue (millions), Length: 1005, dtype: float64

# %%
rev.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1005 entries, Guardians of the Galaxy to Suicide Squad
# Series name: revenue (millions)
# Non-Null Count  Dtype
# --------------  -----
# 1005 non-null   float64
# dtypes: float64(1)
# memory usage: 48.0+ KB

# %%
movies_df.describe()
# Out:
#               rank         year      runtime       rating         votes  \
# count  1005.000000  1004.000000  1004.000000  1004.000000  1.004000e+03
# mean    498.024876  2012.789841   113.205179     6.725697  1.708593e+05
# std     290.220129     3.203104    18.780724     0.944965  1.897133e+05
# min       1.000000  2006.000000    66.000000     1.900000  6.100000e+01
# 25%     247.000000  2010.000000   100.000000     6.200000  3.631950e+04
# 50%     498.000000  2014.000000   111.000000     6.800000  1.111915e+05
# 75%     749.000000  2016.000000   123.000000     7.400000  2.414465e+05
# max    1000.000000  2016.000000   191.000000     9.000000  1.791916e+06
#
#        revenue (millions)   metascore
# count          876.000000  940.000000
# mean            83.862888   58.993617
# std            103.902363   17.179624
# min              0.000000   11.000000
# 25%             13.375000   47.000000
# 50%             48.050000   60.000000
# 75%            115.997500   72.000000
# ...
